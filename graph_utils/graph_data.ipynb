# %%
import numpy as np
import os
import pickle

black_list = []
files = set(os.listdir('../data/train_data_graphs_only_lookback_5_lookahead_10_stride_3'))
for file in files:
    x = pickle.load(open(f'../data/train_data_graphs_only_lookback_5_lookahead_10_stride_3/{file}', 'rb'))
    # if 'embeddings' not in x:
    #     black_list.append(file[:-4])
    # if x['embeddings'].shape[1] != 7:
    print(x['graphs'])
    # break

# print(black_list)
# with open('../data/black_listed_dates.pkl', 'wb') as handle:
#     pickle.dump(black_list, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Graph with 306 nodes and 3162 edges
# Graph with 306 nodes and 249 edges
# Graph with 306 nodes and 1837 edges
# Graph with 306 nodes and 3 edges
# Graph with 306 nodes and 3160 edges
# Graph with 306 nodes and 3757 edges
# Graph with 306 nodes and 3067 edges
# Graph with 306 nodes and 1138 edges
# Graph with 306 nodes and 2382 edges
# Graph with 306 nodes and 16 edges
# Graph with 306 nodes and 1 edges
# Graph with 306 nodes and 2417 edges
# Graph with 306 nodes and 2977 edges
# Graph with 306 nodes and 1 edges
# Graph with 306 nodes and 39 edges
# Graph with 306 nodes and 2268 edges
# Graph with 306 nodes and 2503 edges
# Graph with 306 nodes and 5 edges
# Graph with 306 nodes and 2698 edges
# Graph with 306 nodes and 28 edges
# Graph with 306 nodes and 30 edges
# Graph with 306 nodes and 2234 edges
# Graph with 306 nodes and 185 edges
# Graph with 306 nodes and 13 edges
# Graph with 306 nodes and 3974 edges
# Graph with 306 nodes and 7 edges
# Graph with 306 nodes and 41 edges
# ...
